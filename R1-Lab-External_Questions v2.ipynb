# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 100

# %%
# Read CSV file into a dataframe
Iris = pd.read_csv("Iris_external.csv")

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
print (Iris.head(10))
print(Iris.tail(10))
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
# Overwrite Iris index with first coulmn
Iris.index = Iris ["Sepal Length (in cm)"]
Iris.head(5)
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2]
# Out:
# Sepal Length (in cm)
# 5.1    1.4
# 4.9    1.4
# 4.7    1.3
# 4.6    1.5
# 5.0    1.4
# 5.4    1.7
# 4.6    1.4
# 5.0    1.5
# 4.4    1.4
# 4.9    1.5
# 5.4    1.5
# 4.8    1.6
# 4.8    1.4
# 4.3    1.1
# 5.8    1.2
# 5.7    1.5
# 5.4    1.3
# 5.1    1.4
# 5.7    1.7
# 5.1    1.5
# 5.4    1.7
# 5.1    1.5
# 4.6    1.0
# 5.1    1.7
# 4.8    1.9
# 5.0    1.6
# 5.0    1.6
# 5.2    1.5
# 5.2    1.4
# 4.7    1.6
# 4.8    1.6
# 5.4    1.5
# 5.2    1.5
# 5.5    1.4
# 4.9    1.5
# 5.0    1.2
# 5.5    1.3
# 4.9    1.5
# 4.4    1.3
# 5.1    1.5
# 5.0    1.3
# 4.5    1.3
# 4.4    1.3
# 5.0    1.6
# 5.1    1.9
# 4.8    1.4
# 5.1    1.6
# 4.6    1.4
# 5.3    1.5
# 5.0    1.4
#       ...
# 6.3    6.0
# 5.8    5.1
# 7.1    5.9
# 6.3    5.6
# 6.5    5.8
# 7.6    6.6
# 4.9    4.5
# 7.3    6.3
# 6.7    5.8
# 7.2    6.1
# 6.5    5.1
# 6.4    5.3
# 6.8    5.5
# 5.7    5.0
# 5.8    5.1
# 6.4    5.3
# 6.5    5.5
# 7.7    6.7
# 7.7    6.9
# 6.0    5.0
# 6.9    5.7
# 5.6    4.9
# 7.7    6.7
# 6.3    4.9
# 6.7    5.7
# 7.2    6.0
# 6.2    4.8
# 6.1    4.9
# 6.4    5.6
# 7.2    5.8
# 7.4    6.1
# 7.9    6.4
# 6.4    5.6
# 6.3    5.1
# 6.1    5.6
# 7.7    6.1
# 6.3    5.6
# 6.4    5.5
# 6.0    4.8
# 6.9    5.4
# 6.7    5.6
# 6.9    5.1
# 5.8    5.1
# 6.8    5.9
# 6.7    5.7
# 6.7    5.2
# 6.3    5.0
# 6.5    5.2
# 6.2    5.4
# 5.9    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.iloc[range(10),[0,1]]
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
print(Iris[Iris["Class"]=="Iris-setosa"])
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1
# 5.4                                    5.4                  3.7
# 4.8                                    4.8                  3.4
# 4.8                                    4.8                  3.0
# 4.3                                    4.3                  3.0
# 5.8                                    5.8                  4.0
# 5.7                                    5.7                  4.4
# 5.4                                    5.4                  3.9
# 5.1                                    5.1                  3.5
# 5.7                                    5.7                  3.8
# 5.1                                    5.1                  3.8
# 5.4                                    5.4                  3.4
# 5.1                                    5.1                  3.7
# 4.6                                    4.6                  3.6
# 5.1                                    5.1                  3.3
# 4.8                                    4.8                  3.4
# 5.0                                    5.0                  3.0
# 5.0                                    5.0                  3.4
# 5.2                                    5.2                  3.5
# 5.2                                    5.2                  3.4
# 4.7                                    4.7                  3.2
# 4.8                                    4.8                  3.1
# 5.4                                    5.4                  3.4
# 5.2                                    5.2                  4.1
# 5.5                                    5.5                  4.2
# 4.9                                    4.9                  3.1
# 5.0                                    5.0                  3.2
# 5.5                                    5.5                  3.5
# 4.9                                    4.9                  3.1
# 4.4                                    4.4                  3.0
# 5.1                                    5.1                  3.4
# 5.0                                    5.0                  3.5
# 4.5                                    4.5                  2.3
# 4.4                                    4.4                  3.2
# 5.0                                    5.0                  3.5
# 5.1                                    5.1                  3.8
# 4.8                                    4.8                  3.0
# 5.1                                    5.1                  3.8
# 4.6                                    4.6                  3.2
# 5.3                                    5.3                  3.7
# 5.0                                    5.0                  3.3
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa
# 5.4                                    1.7                  0.4  Iris-setosa
# 4.6                                    1.4                  0.3  Iris-setosa
# 5.0                                    1.5                  0.2  Iris-setosa
# 4.4                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.5                  0.1  Iris-setosa
# 5.4                                    1.5                  0.2  Iris-setosa
# 4.8                                    1.6                  0.2  Iris-setosa
# 4.8                                    1.4                  0.1  Iris-setosa
# 4.3                                    1.1                  0.1  Iris-setosa
# 5.8                                    1.2                  0.2  Iris-setosa
# 5.7                                    1.5                  0.4  Iris-setosa
# 5.4                                    1.3                  0.4  Iris-setosa
# 5.1                                    1.4                  0.3  Iris-setosa
# 5.7                                    1.7                  0.3  Iris-setosa
# 5.1                                    1.5                  0.3  Iris-setosa
# 5.4                                    1.7                  0.2  Iris-setosa
# 5.1                                    1.5                  0.4  Iris-setosa
# 4.6                                    1.0                  0.2  Iris-setosa
# 5.1                                    1.7                  0.5  Iris-setosa
# 4.8                                    1.9                  0.2  Iris-setosa
# 5.0                                    1.6                  0.2  Iris-setosa
# 5.0                                    1.6                  0.4  Iris-setosa
# 5.2                                    1.5                  0.2  Iris-setosa
# 5.2                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.6                  0.2  Iris-setosa
# 4.8                                    1.6                  0.2  Iris-setosa
# 5.4                                    1.5                  0.4  Iris-setosa
# 5.2                                    1.5                  0.1  Iris-setosa
# 5.5                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.5                  0.1  Iris-setosa
# 5.0                                    1.2                  0.2  Iris-setosa
# 5.5                                    1.3                  0.2  Iris-setosa
# 4.9                                    1.5                  0.1  Iris-setosa
# 4.4                                    1.3                  0.2  Iris-setosa
# 5.1                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.3                  0.3  Iris-setosa
# 4.5                                    1.3                  0.3  Iris-setosa
# 4.4                                    1.3                  0.2  Iris-setosa
# 5.0                                    1.6                  0.6  Iris-setosa
# 5.1                                    1.9                  0.4  Iris-setosa
# 4.8                                    1.4                  0.3  Iris-setosa
# 5.1                                    1.6                  0.2  Iris-setosa
# 4.6                                    1.4                  0.2  Iris-setosa
# 5.3                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
SepalExtra = Iris["Sepal Length (in cm)"]*Iris["Sepal Width in (cm)"]
#print (SepalExtra)

# %%
Iris["SepalExtra"] = SepalExtra
Iris.head(3)
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
#
#                       Petal length (in cm)  Petal width (in cm)        Class  \
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
#
#                       SepalExtra
# Sepal Length (in cm)
# 5.1                        17.85
# 4.9                        14.70
# 4.7                        15.04

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
mean = np.mean(Iris)
print ("**Mean is: \n",mean)
var = np.var(Iris)
print ("**Varience is : \n",var)
# Out:
# **Mean is:
#  Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64
# **Varience is :
#  Sepal Length (in cm)     0.681122
# Sepal Width in (cm)      0.186751
# Petal length (in cm)     3.092425
# Petal width (in cm)      0.578532
# SepalExtra              11.272436
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def prn(length,width):
    print (length,width)

# %%
prn(Iris.iloc[4,0],Iris.iloc[4,1])
# Out:
# 5.0 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
# Find range of all columns excluding Class 
Range = np.max(Iris.iloc[:,[0,1,2,3,5]])-np.min(Iris.iloc[:,[0,1,2,3,5]]) # Ignoring column Index and Class
print (Range)
# Out:
# Sepal Length (in cm)     3.60
# Sepal Width in (cm)      2.40
# Petal length (in cm)     5.90
# Petal width (in cm)      2.40
# SepalExtra              20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values(by='Petal width (in cm)',ascending=True)
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.2                                    5.2                  4.1
# 4.3                                    4.3                  3.0
# 4.9                                    4.9                  3.1
# 4.9                                    4.9                  3.1
# 4.8                                    4.8                  3.0
# 4.9                                    4.9                  3.1
# 5.1                                    5.1                  3.5
# 5.2                                    5.2                  3.5
# 5.2                                    5.2                  3.4
# 4.7                                    4.7                  3.2
# 4.8                                    4.8                  3.1
# 5.5                                    5.5                  4.2
# 5.5                                    5.5                  3.5
# 4.4                                    4.4                  3.0
# 5.1                                    5.1                  3.4
# 4.4                                    4.4                  3.2
# 5.1                                    5.1                  3.8
# 4.6                                    4.6                  3.2
# 5.3                                    5.3                  3.7
# 5.0                                    5.0                  3.3
# 5.0                                    5.0                  3.0
# 4.8                                    4.8                  3.4
# 5.0                                    5.0                  3.2
# 4.6                                    4.6                  3.1
# 4.7                                    4.7                  3.2
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 5.4                                    5.4                  3.7
# 5.0                                    5.0                  3.6
# 4.8                                    4.8                  3.4
# 5.8                                    5.8                  4.0
# 4.9                                    4.9                  3.0
# 5.4                                    5.4                  3.4
# 4.6                                    4.6                  3.6
# 5.1                                    5.1                  3.5
# 5.7                                    5.7                  3.8
# 5.1                                    5.1                  3.8
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.5
# 4.5                                    4.5                  2.3
# 4.8                                    4.8                  3.0
# 5.7                                    5.7                  4.4
# 5.4                                    5.4                  3.9
# 5.0                                    5.0                  3.4
# 5.4                                    5.4                  3.9
# 5.1                                    5.1                  3.7
# 5.1                                    5.1                  3.8
# 5.4                                    5.4                  3.4
# 5.1                                    5.1                  3.3
# 5.0                                    5.0                  3.5
# ...                                    ...                  ...
# 6.0                                    6.0                  3.4
# 6.0                                    6.0                  2.7
# 4.9                                    4.9                  2.5
# 6.7                                    6.7                  3.0
# 6.5                                    6.5                  3.0
# 6.4                                    6.4                  3.1
# 6.1                                    6.1                  3.0
# 6.2                                    6.2                  2.8
# 7.2                                    7.2                  3.2
# 6.3                                    6.3                  2.7
# 6.0                                    6.0                  3.0
# 5.9                                    5.9                  3.0
# 5.9                                    5.9                  3.2
# 6.3                                    6.3                  2.9
# 7.3                                    7.3                  2.9
# 6.7                                    6.7                  2.5
# 7.4                                    7.4                  2.8
# 6.3                                    6.3                  2.5
# 5.8                                    5.8                  2.7
# 5.8                                    5.8                  2.7
# 6.4                                    6.4                  2.7
# 5.6                                    5.6                  2.8
# 7.7                                    7.7                  2.8
# 6.5                                    6.5                  3.0
# 5.7                                    5.7                  2.5
# 7.9                                    7.9                  3.8
# 6.5                                    6.5                  3.2
# 6.9                                    6.9                  3.1
# 7.1                                    7.1                  3.0
# 6.8                                    6.8                  3.0
# 7.6                                    7.6                  3.0
# 6.7                                    6.7                  3.3
# 6.4                                    6.4                  2.8
# 7.7                                    7.7                  3.8
# 6.4                                    6.4                  2.8
# 6.5                                    6.5                  3.0
# 6.9                                    6.9                  3.2
# 6.4                                    6.4                  3.2
# 6.2                                    6.2                  3.4
# 6.9                                    6.9                  3.1
# 6.8                                    6.8                  3.2
# 6.7                                    6.7                  3.0
# 7.7                                    7.7                  2.6
# 7.7                                    7.7                  3.0
# 6.3                                    6.3                  3.4
# 6.7                                    6.7                  3.1
# 5.8                                    5.8                  2.8
# 6.3                                    6.3                  3.3
# 6.7                                    6.7                  3.3
# 7.2                                    7.2                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)  \
# Sepal Length (in cm)
# 5.2                                    1.5                  0.1
# 4.3                                    1.1                  0.1
# 4.9                                    1.5                  0.1
# 4.9                                    1.5                  0.1
# 4.8                                    1.4                  0.1
# 4.9                                    1.5                  0.1
# 5.1                                    1.4                  0.2
# 5.2                                    1.5                  0.2
# 5.2                                    1.4                  0.2
# 4.7                                    1.6                  0.2
# 4.8                                    1.6                  0.2
# 5.5                                    1.4                  0.2
# 5.5                                    1.3                  0.2
# 4.4                                    1.3                  0.2
# 5.1                                    1.5                  0.2
# 4.4                                    1.3                  0.2
# 5.1                                    1.6                  0.2
# 4.6                                    1.4                  0.2
# 5.3                                    1.5                  0.2
# 5.0                                    1.4                  0.2
# 5.0                                    1.6                  0.2
# 4.8                                    1.9                  0.2
# 5.0                                    1.2                  0.2
# 4.6                                    1.5                  0.2
# 4.7                                    1.3                  0.2
# 5.0                                    1.5                  0.2
# 4.4                                    1.4                  0.2
# 5.4                                    1.5                  0.2
# 5.0                                    1.4                  0.2
# 4.8                                    1.6                  0.2
# 5.8                                    1.2                  0.2
# 4.9                                    1.4                  0.2
# 5.4                                    1.7                  0.2
# 4.6                                    1.0                  0.2
# 5.1                                    1.4                  0.3
# 5.7                                    1.7                  0.3
# 5.1                                    1.5                  0.3
# 4.6                                    1.4                  0.3
# 5.0                                    1.3                  0.3
# 4.5                                    1.3                  0.3
# 4.8                                    1.4                  0.3
# 5.7                                    1.5                  0.4
# 5.4                                    1.3                  0.4
# 5.0                                    1.6                  0.4
# 5.4                                    1.7                  0.4
# 5.1                                    1.5                  0.4
# 5.1                                    1.9                  0.4
# 5.4                                    1.5                  0.4
# 5.1                                    1.7                  0.5
# 5.0                                    1.6                  0.6
# ...                                    ...                  ...
# 6.0                                    4.5                  1.6
# 6.0                                    5.1                  1.6
# 4.9                                    4.5                  1.7
# 6.7                                    5.0                  1.7
# 6.5                                    5.5                  1.8
# 6.4                                    5.5                  1.8
# 6.1                                    4.9                  1.8
# 6.2                                    4.8                  1.8
# 7.2                                    6.0                  1.8
# 6.3                                    4.9                  1.8
# 6.0                                    4.8                  1.8
# 5.9                                    5.1                  1.8
# 5.9                                    4.8                  1.8
# 6.3                                    5.6                  1.8
# 7.3                                    6.3                  1.8
# 6.7                                    5.8                  1.8
# 7.4                                    6.1                  1.9
# 6.3                                    5.0                  1.9
# 5.8                                    5.1                  1.9
# 5.8                                    5.1                  1.9
# 6.4                                    5.3                  1.9
# 5.6                                    4.9                  2.0
# 7.7                                    6.7                  2.0
# 6.5                                    5.2                  2.0
# 5.7                                    5.0                  2.0
# 7.9                                    6.4                  2.0
# 6.5                                    5.1                  2.0
# 6.9                                    5.4                  2.1
# 7.1                                    5.9                  2.1
# 6.8                                    5.5                  2.1
# 7.6                                    6.6                  2.1
# 6.7                                    5.7                  2.1
# 6.4                                    5.6                  2.1
# 7.7                                    6.7                  2.2
# 6.4                                    5.6                  2.2
# 6.5                                    5.8                  2.2
# 6.9                                    5.7                  2.3
# 6.4                                    5.3                  2.3
# 6.2                                    5.4                  2.3
# 6.9                                    5.1                  2.3
# 6.8                                    5.9                  2.3
# 6.7                                    5.2                  2.3
# 7.7                                    6.9                  2.3
# 7.7                                    6.1                  2.3
# 6.3                                    5.6                  2.4
# 6.7                                    5.6                  2.4
# 5.8                                    5.1                  2.4
# 6.3                                    6.0                  2.5
# 6.7                                    5.7                  2.5
# 7.2                                    6.1                  2.5
#
#                                 Class  SepalExtra
# Sepal Length (in cm)
# 5.2                       Iris-setosa       21.32
# 4.3                       Iris-setosa       12.90
# 4.9                       Iris-setosa       15.19
# 4.9                       Iris-setosa       15.19
# 4.8                       Iris-setosa       14.40
# 4.9                       Iris-setosa       15.19
# 5.1                       Iris-setosa       17.85
# 5.2                       Iris-setosa       18.20
# 5.2                       Iris-setosa       17.68
# 4.7                       Iris-setosa       15.04
# 4.8                       Iris-setosa       14.88
# 5.5                       Iris-setosa       23.10
# 5.5                       Iris-setosa       19.25
# 4.4                       Iris-setosa       13.20
# 5.1                       Iris-setosa       17.34
# 4.4                       Iris-setosa       14.08
# 5.1                       Iris-setosa       19.38
# 4.6                       Iris-setosa       14.72
# 5.3                       Iris-setosa       19.61
# 5.0                       Iris-setosa       16.50
# 5.0                       Iris-setosa       15.00
# 4.8                       Iris-setosa       16.32
# 5.0                       Iris-setosa       16.00
# 4.6                       Iris-setosa       14.26
# 4.7                       Iris-setosa       15.04
# 5.0                       Iris-setosa       17.00
# 4.4                       Iris-setosa       12.76
# 5.4                       Iris-setosa       19.98
# 5.0                       Iris-setosa       18.00
# 4.8                       Iris-setosa       16.32
# 5.8                       Iris-setosa       23.20
# 4.9                       Iris-setosa       14.70
# 5.4                       Iris-setosa       18.36
# 4.6                       Iris-setosa       16.56
# 5.1                       Iris-setosa       17.85
# 5.7                       Iris-setosa       21.66
# 5.1                       Iris-setosa       19.38
# 4.6                       Iris-setosa       15.64
# 5.0                       Iris-setosa       17.50
# 4.5                       Iris-setosa       10.35
# 4.8                       Iris-setosa       14.40
# 5.7                       Iris-setosa       25.08
# 5.4                       Iris-setosa       21.06
# 5.0                       Iris-setosa       17.00
# 5.4                       Iris-setosa       21.06
# 5.1                       Iris-setosa       18.87
# 5.1                       Iris-setosa       19.38
# 5.4                       Iris-setosa       18.36
# 5.1                       Iris-setosa       16.83
# 5.0                       Iris-setosa       17.50
# ...                               ...         ...
# 6.0                   Iris-versicolor       20.40
# 6.0                   Iris-versicolor       16.20
# 4.9                    Iris-virginica       12.25
# 6.7                   Iris-versicolor       20.10
# 6.5                    Iris-virginica       19.50
# 6.4                    Iris-virginica       19.84
# 6.1                    Iris-virginica       18.30
# 6.2                    Iris-virginica       17.36
# 7.2                    Iris-virginica       23.04
# 6.3                    Iris-virginica       17.01
# 6.0                    Iris-virginica       18.00
# 5.9                    Iris-virginica       17.70
# 5.9                   Iris-versicolor       18.88
# 6.3                    Iris-virginica       18.27
# 7.3                    Iris-virginica       21.17
# 6.7                    Iris-virginica       16.75
# 7.4                    Iris-virginica       20.72
# 6.3                    Iris-virginica       15.75
# 5.8                    Iris-virginica       15.66
# 5.8                    Iris-virginica       15.66
# 6.4                    Iris-virginica       17.28
# 5.6                    Iris-virginica       15.68
# 7.7                    Iris-virginica       21.56
# 6.5                    Iris-virginica       19.50
# 5.7                    Iris-virginica       14.25
# 7.9                    Iris-virginica       30.02
# 6.5                    Iris-virginica       20.80
# 6.9                    Iris-virginica       21.39
# 7.1                    Iris-virginica       21.30
# 6.8                    Iris-virginica       20.40
# 7.6                    Iris-virginica       22.80
# 6.7                    Iris-virginica       22.11
# 6.4                    Iris-virginica       17.92
# 7.7                    Iris-virginica       29.26
# 6.4                    Iris-virginica       17.92
# 6.5                    Iris-virginica       19.50
# 6.9                    Iris-virginica       22.08
# 6.4                    Iris-virginica       20.48
# 6.2                    Iris-virginica       21.08
# 6.9                    Iris-virginica       21.39
# 6.8                    Iris-virginica       21.76
# 6.7                    Iris-virginica       20.10
# 7.7                    Iris-virginica       20.02
# 7.7                    Iris-virginica       23.10
# 6.3                    Iris-virginica       21.42
# 6.7                    Iris-virginica       20.77
# 5.8                    Iris-virginica       16.24
# 6.3                    Iris-virginica       20.79
# 6.7                    Iris-virginica       22.11
# 7.2                    Iris-virginica       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris.drop('SepalExtra',axis = 1, inplace = True)
Iris.head(5)
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.iloc[:10,:3]
IrisSubset.head(5)
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)
# Sepal Length (in cm)
# 5.1                                    1.4
# 4.9                                    1.4
# 4.7                                    1.3
# 4.6                                    1.5
# 5.0                                    1.4

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
# Read as CSV with Tab seperator
hr_data = pd.read_csv("HR_external.txt",sep="\t")

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
print ("Rows: {0}, columns: {1}".format(hr_data.shape[0],hr_data.shape[1]))
# Out:
# Rows: 1470, columns: 35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
# one way is to use .info
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Individual                  1470 non-null object
# Attrition                   1470 non-null object
# Age                         1470 non-null int64
# BusinessTravel              1470 non-null int64
# DailyRate                   1470 non-null int64
# Department                  1470 non-null int64
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null int64
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null int64
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null int64
# JobSatisfaction             1470 non-null int64
# MaritalStatus               1470 non-null int64
# MonthlyIncome               1470 non-null int64
# MonthlyRate                 1470 non-null int64
# NumCompaniesWorked          1470 non-null int64
# OverTime                    1470 non-null int64
# PercentSalaryHike           1470 non-null int64
# PerformanceRating           1470 non-null int64
# RelationshipSatisfaction    1470 non-null int64
# StandardHours               1470 non-null int64
# StockOptionLevel            1470 non-null int64
# TotalWorkingYears           1470 non-null int64
# TrainingTimesLastYear       1470 non-null int64
# WorkLifeBalance             1470 non-null int64
# YearsAtCompany              1470 non-null int64
# YearsInCurrentRole          1470 non-null int64
# YearsSinceLastPromotion     1470 non-null int64
# YearsWithCurrManager        1470 non-null int64
# dtypes: int64(33), object(2)
# memory usage: 402.0+ KB

# %%
# other way is to check data type of each column
for data in hr_data.columns:
    print ("""Data Type of "{0}" is {1}""".format(data,type(data)))
# Out:
# Data Type of "Individual " is <class 'str'>
# Data Type of "Attrition" is <class 'str'>
# Data Type of "Age" is <class 'str'>
# Data Type of "BusinessTravel" is <class 'str'>
# Data Type of "DailyRate" is <class 'str'>
# Data Type of "Department" is <class 'str'>
# Data Type of "DistanceFromHome" is <class 'str'>
# Data Type of "Education" is <class 'str'>
# Data Type of "EducationField" is <class 'str'>
# Data Type of "EmployeeCount" is <class 'str'>
# Data Type of "EmployeeNumber" is <class 'str'>
# Data Type of "EnvironmentSatisfaction" is <class 'str'>
# Data Type of "Gender" is <class 'str'>
# Data Type of "HourlyRate" is <class 'str'>
# Data Type of "JobInvolvement" is <class 'str'>
# Data Type of "JobLevel" is <class 'str'>
# Data Type of "JobRole" is <class 'str'>
# Data Type of "JobSatisfaction" is <class 'str'>
# Data Type of "MaritalStatus" is <class 'str'>
# Data Type of "MonthlyIncome" is <class 'str'>
# Data Type of "MonthlyRate" is <class 'str'>
# Data Type of "NumCompaniesWorked" is <class 'str'>
# Data Type of "OverTime" is <class 'str'>
# Data Type of "PercentSalaryHike" is <class 'str'>
# Data Type of "PerformanceRating" is <class 'str'>
# Data Type of "RelationshipSatisfaction" is <class 'str'>
# Data Type of "StandardHours" is <class 'str'>
# Data Type of "StockOptionLevel" is <class 'str'>
# Data Type of "TotalWorkingYears" is <class 'str'>
# Data Type of "TrainingTimesLastYear" is <class 'str'>
# Data Type of "WorkLifeBalance" is <class 'str'>
# Data Type of "YearsAtCompany" is <class 'str'>
# Data Type of "YearsInCurrentRole" is <class 'str'>
# Data Type of "YearsSinceLastPromotion" is <class 'str'>
# Data Type of "YearsWithCurrManager" is <class 'str'>

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hr_data.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# 11     29               1        153           2                15          2
# 12     31               1        670           2                26          1
# 13     34               1       1346           2                19          2
# 14     28               1        103           2                24          3
# 15     29               1       1389           2                21          4
# 16     32               1        334           2                 5          2
# 17     22               3       1123           2                16          2
# 18     53               1       1219           1                 2          4
# 19     38               1        371           2                 2          3
# 20     24               3        673           2                11          2
# 21     36               1       1218           1                 9          4
# 22     34               1        419           2                 7          4
# 23     21               1        391           2                15          2
# 24     34               1        699           2                 6          1
# 25     53               1       1282           2                 5          3
# 26     32               2       1125           2                16          1
# 27     42               1        691           1                 8          4
# 28     44               1        477           2                 7          4
# 29     46               1        705           1                 2          4
# 30     33               1        924           2                 2          3
# 31     44               1       1459           2                10          4
# 32     30               1        125           2                 9          2
# 33     39               1        895           1                 5          3
# 34     24               1        813           2                 1          3
# 35     43               1       1273           2                 2          2
# 36     50               1        869           1                 3          2
# 37     35               1        890           1                 2          3
# 38     36               1        852           2                 5          4
# 39     33               2       1141           1                 1          3
# 40     35               1        464           2                 4          2
# 41     27               1       1240           2                 2          4
# 42     26               1       1357           2                25          3
# 43     27               2        994           1                 8          3
# 44     30               2        721           2                 1          2
# 45     41               1       1360           2                12          3
# 46     34               3       1065           1                23          4
# 47     37               1        408           2                19          2
# 48     46               2       1211           1                 5          4
# 49     35               1       1229           2                 8          1
# ...   ...             ...        ...         ...               ...        ...
# 1420   41               1        642           2                 1          3
# 1421   47               3       1162           2                 1          1
# 1422   35               1       1490           2                11          4
# 1423   22               1        581           2                 1          2
# 1424   35               1       1395           2                 9          4
# 1425   33               1        501           2                15          2
# 1426   32               1        267           2                29          4
# 1427   40               1        543           2                 1          4
# 1428   32               1        234           1                 1          4
# 1429   39               1        116           2                24          1
# 1430   38               1        201           2                10          3
# 1431   32               1        801           1                 1          4
# 1432   37               1        161           2                10          3
# 1433   25               1       1382           1                 8          2
# 1434   52               3        585           1                29          4
# 1435   44               1       1037           2                 1          3
# 1436   21               1        501           1                 5          1
# 1437   39               3        105           2                 9          3
# 1438   23               2        638           1                 9          3
# 1439   36               1        557           1                 3          3
# 1440   36               2        688           2                 4          2
# 1441   56               3        667           2                 1          4
# 1442   29               1       1092           2                 1          4
# 1443   42               1        300           2                 2          3
# 1444   56               1        310           2                 7          2
# 1445   41               1        582           2                28          4
# 1446   34               1        704           1                28          3
# 1447   36               3        301           1                15          4
# 1448   41               1        930           1                 3          3
# 1449   32               1        529           2                 2          3
# 1450   35               1       1146           3                26          4
# 1451   38               1        345           1                10          2
# 1452   50               2        878           1                 1          4
# 1453   36               1       1120           1                11          4
# 1454   45               1        374           1                20          3
# 1455   40               1       1322           2                 2          4
# 1456   35               2       1199           2                18          4
# 1457   40               1       1194           2                 2          4
# 1458   35               1        287           2                 1          4
# 1459   29               1       1378           2                13          2
# 1460   29               1        468           2                28          4
# 1461   50               1        410           1                28          3
# 1462   39               1        722           1                24          1
# 1463   31               3        325           2                 5          3
# 1464   26               1       1167           1                 5          3
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# 5                  1              1
# 6                  2              1
# 7                  1              1
# 8                  1              1
# 9                  2              1
# 10                 2              1
# 11                 1              1
# 12                 1              1
# 13                 2              1
# 14                 1              1
# 15                 1              1
# 16                 1              1
# 17                 2              1
# 18                 1              1
# 19                 1              1
# 20                 6              1
# 21                 1              1
# 22                 1              1
# 23                 1              1
# 24                 2              1
# 25                 6              1
# 26                 1              1
# 27                 3              1
# 28                 2              1
# 29                 3              1
# 30                 2              1
# 31                 6              1
# 32                 2              1
# 33                 4              1
# 34                 2              1
# 35                 2              1
# 36                 3              1
# 37                 3              1
# 38                 1              1
# 39                 1              1
# 40                 6              1
# 41                 1              1
# 42                 1              1
# 43                 1              1
# 44                 2              1
# 45                 4              1
# 46                 3              1
# 47                 1              1
# 48                 3              1
# 49                 1              1
# ...              ...            ...
# 1420               1              1
# 1421               2              1
# 1422               2              1
# 1423               1              1
# 1424               2              1
# 1425               2              1
# 1426               1              1
# 1427               1              1
# 1428               2              1
# 1429               1              1
# 1430               2              1
# 1431               3              1
# 1432               1              1
# 1433               6              1
# 1434               1              1
# 1435               2              1
# 1436               2              1
# 1437               1              1
# 1438               3              1
# 1439               2              1
# 1440               1              1
# 1441               1              1
# 1442               2              1
# 1443               1              1
# 1444               4              1
# 1445               1              1
# 1446               3              1
# 1447               3              1
# 1448               1              1
# 1449               4              1
# 1450               1              1
# 1451               1              1
# 1452               1              1
# 1453               3              1
# 1454               1              1
# 1455               1              1
# 1456               1              1
# 1457               2              1
# 1458               1              1
# 1459               6              1
# 1460               2              1
# 1461               3              1
# 1462               3              1
# 1463               2              1
# 1464               6              1
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
# assuming male is represented by 2
male_count = len(hr_data["Gender"][hr_data["Gender"]==2])
print ("No of Male (2) in the data is: ", male_count)
# Out:
# No of Male (2) in the data is:  588

# %%
# assuming female is represented by 1
female_count = len(hr_data["Gender"][hr_data["Gender"]==1])
print ("No of FeMale (1) in the data is: ", female_count)
# Out:
# No of FeMale (1) in the data is:  882

# %%
# Total values in "Gender Column"
len(hr_data["Gender"])
# Out:
# 1470

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
q1 = hr_data["Age"].quantile(q=.25)
q3 = hr_data["Age"].quantile(q=.75)
iqr = q3-q1
print ("Q1 is {0} \nQ3 is {1} \nIQR is {2}".format(q1,q3,iqr))
# Out:
# Q1 is 30.0
# Q3 is 43.0
# IQR is 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
mn = round(np.mean(hr_data["DailyRate"]),2)
nd = round (np.median(hr_data["DailyRate"]),2)
var = round(np.var(hr_data["DailyRate"]),2)
print ("For Age:  \n Mean is {0}, \n Median is {1}, \n Varinece is {2}".format(mn,nd,var))
# Out:
# For Age:
#  Mean is 802.49,
#  Median is 802.0,
#  Varinece is 162708.83

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Countplot for Univariate Catogerical data analysis
sns.countplot(hr_data["Attrition"])

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
# Continious Univariate - strip plot 
sns.stripplot(hr_data["TotalWorkingYears"])

# %%
# Continious Univariate - Box plot to find outliers
sns.boxplot(hr_data["TotalWorkingYears"])

# %%
#  Continious Univariate - Histogram 
plt.hist(hr_data["TotalWorkingYears"],bins=20)
plt.show()

# %%
#  Continious Univariate - Histogram with KDE
sns.distplot(hr_data["TotalWorkingYears"])

# %%
e_time = dt.now()
print (s_time,"\n",e_time)
# Out:
# 2019-02-09 17:51:30.665412
#  2019-02-09 17:51:33.099060
